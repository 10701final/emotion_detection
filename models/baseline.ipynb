# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.python.lib.io import file_io

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras import losses
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.python.keras.preprocessing import image_dataset

from imutils.face_utils import FaceAligner
from imutils.face_utils import rect_to_bb
import imutils, cv2, dlib

# %matplotlib inline

# %%
EPOCHS = 150
BS = 128
DROPOUT_RATE = 0.3
SGD_LEARNING_RATE = 0.01
SGD_DECAY = 0.0001

# %%
model = Sequential()
model.add(BatchNormalization(input_shape=(48,48,3)))
model.add(Conv2D(32, (3, 3), activation='relu',padding='same', input_shape=(48,48,3),name="conv1"))
model.add(BatchNormalization())
#model.add(MaxPooling2D(pool_size=(2, 2),name="maxpool1"))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu',padding='same',name="conv2"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2),name="maxpool2"))         
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu',padding='same',name="conv3"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2),name="maxpool3"))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu',padding='same',name="conv4"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2),name="maxpool4"))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(1024, activation='relu',name='fc1'))
model.add(Dropout(DROPOUT_RATE))
model.add(BatchNormalization())
model.add(Dense(7, activation='softmax',name='fcsoftmax'))

sgd = SGD(lr=SGD_LEARNING_RATE,momentum=0.9, decay=SGD_DECAY, nesterov=True)
model.compile(loss="categorical_crossentropy", optimizer=sgd,metrics=['accuracy'])

# checkpoint
cp_filepath='./model/Baseline-weights-best.hdf5'
rlrop = keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy',mode='max',factor=0.5, patience=10, min_lr=0.00001, verbose=1)
checkpoint = ModelCheckpoint(cp_filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [rlrop,checkpoint]

# %%
# %%bash
# root='./../dataset/train/'
# IFS=$(echo -en "\n\b")
# (for dir in $(ls -1 "$root")
#     do printf "$dir: " && ls -i "$root$dir" | wc -l
#  done)
# Out:
# angry:     3995
# disgust:      436
# fear:     4097
# happy:     7215
# neutral:     4965
# sad:     4830
# surprise:     3171

# %%
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('./shape_predictor_68_face_landmarks.dat')
fa = FaceAligner(predictor, desiredLeftEye=(0.3,0.3), desiredFaceWidth=48)

# %%
def preprocessing(path, filename):
    image = cv2.imread(path)
    image = imutils.resize(image, width=800)
    face = cv2.normalize(image, None, 0, 255, cv2.NORM_MINMAX)
    gray_face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)
    rect = detector(face, 1)
    if (len(rect) > 0):
        rect = rect[0]
        face_aligned = fa.align(face, gray_face, rect)
        cv2.imwrite(filename, face_aligned)

# %%
source = './../dataset'
target = './../dataset2'
for dataset in os.listdir(source):
    dataset_dir = source+'/'+dataset
    if os.path.isdir(dataset_dir):
        for category in os.listdir(dataset_dir):
            category_dir = dataset_dir+'/'+category
            if os.path.isdir(category_dir):
                for file in os.listdir(category_dir):
                    path = category_dir+'/'+file
                    filename = target+'/'+dataset+'/'+category+'/'+file
                    if os.path.isfile(path) and not os.path.exists(filename+'.jpg'):
                        preprocessing(path, filename)
                print("Finish preprocessing {} in {}...".format(category, dataset))
print("Finish preprocessing!")
# Out:
# Finish preprocessing happy in test...
# Finish preprocessing sad in test...
# Finish preprocessing fear in test...
# Finish preprocessing surprise in test...
# Finish preprocessing neutral in test...
# Finish preprocessing angry in test...
# Finish preprocessing disgust in test...
# Finish preprocessing happy in train...
# Finish preprocessing sad in train...
# Finish preprocessing fear in train...
# Finish preprocessing surprise in train...
# Finish preprocessing neutral in train...
# Finish preprocessing angry in train...
# Finish preprocessing disgust in train...
# Finish preprocessing!

# %%
def load_data(train_path, test_path):
    train_data = image_dataset.image_dataset_from_directory(
            train_path, 
            label_mode='categorical',
            batch_size=BS,
            image_size=(48, 48), 
            shuffle=True, 
            seed=1337,
            validation_split=0.2,
            subset="training")
    val_data = image_dataset.image_dataset_from_directory(
            train_path, 
            label_mode='categorical',
            batch_size=BS,
            image_size=(48, 48), 
            shuffle=True, 
            seed=1337,
            validation_split=0.2,
            subset="validation")
    test_data = image_dataset.image_dataset_from_directory(
            test_path, 
            label_mode='categorical',
            batch_size=BS,
            image_size=(48, 48), 
            shuffle=True)
    return train_data, val_data, test_data

# %%
# configuration for better performance
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
train_ds, val_ds, test_ds = load_data(target+'/train', target+'/test')
# Out:
# Found 22035 files belonging to 7 classes.
# Using 17628 files for training.
# Found 22035 files belonging to 7 classes.
# Using 4407 files for validation.
# Found 5512 files belonging to 7 classes.

# %%
train_ds.take(1)
# Out:
# <TakeDataset shapes: ((None, 48, 48, 3), (None, 7)), types: (tf.float32, tf.float32)>

# %%
history = model.fit(
    train_ds, 
    validation_data=val_ds, 
    shuffle=True, 
    epochs=EPOCHS,
    callbacks=callbacks_list,
    use_multiprocessing=False,)
# Out:
# ve from 0.66644
# 138/138 [==============================] - 72s 520ms/step - loss: 0.0731 - accuracy: 0.9769 - val_loss: 1.5696 - val_accuracy: 0.6649
# Epoch 84/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0711 - accuracy: 0.9767
# Epoch 00084: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 72s 523ms/step - loss: 0.0711 - accuracy: 0.9767 - val_loss: 1.5679 - val_accuracy: 0.6621
# Epoch 85/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0754 - accuracy: 0.9757
# Epoch 00085: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 72s 520ms/step - loss: 0.0754 - accuracy: 0.9757 - val_loss: 1.5475 - val_accuracy: 0.6630
# Epoch 86/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0755 - accuracy: 0.9754
# Epoch 00086: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 73s 526ms/step - loss: 0.0755 - accuracy: 0.9754 - val_loss: 1.5568 - val_accuracy: 0.6635
# Epoch 87/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0718 - accuracy: 0.9779
# Epoch 00087: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 71s 513ms/step - loss: 0.0718 - accuracy: 0.9779 - val_loss: 1.5361 - val_accuracy: 0.6639
# Epoch 88/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0683 - accuracy: 0.9775
# Epoch 00088: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 71s 517ms/step - loss: 0.0683 - accuracy: 0.9775 - val_loss: 1.5564 - val_accuracy: 0.6653
# Epoch 89/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0734 - accuracy: 0.9771
# Epoch 00089: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 71s 517ms/step - loss: 0.0734 - accuracy: 0.9771 - val_loss: 1.5536 - val_accuracy: 0.6651
# Epoch 90/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0720 - accuracy: 0.9765
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
#
# Epoch 00090: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 71s 515ms/step - loss: 0.0720 - accuracy: 0.9765 - val_loss: 1.5493 - val_accuracy: 0.6633
# Epoch 91/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0682 - accuracy: 0.9780
# Epoch 00091: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 71s 515ms/step - loss: 0.0682 - accuracy: 0.9780 - val_loss: 1.5639 - val_accuracy: 0.6639
# Epoch 92/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0709 - accuracy: 0.9775
# Epoch 00092: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 72s 519ms/step - loss: 0.0709 - accuracy: 0.9775 - val_loss: 1.5593 - val_accuracy: 0.6642
# Epoch 93/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9774
# Epoch 00093: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 72s 519ms/step - loss: 0.0681 - accuracy: 0.9774 - val_loss: 1.5692 - val_accuracy: 0.6637
# Epoch 94/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 0.9773
# Epoch 00094: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 71s 518ms/step - loss: 0.0708 - accuracy: 0.9773 - val_loss: 1.5739 - val_accuracy: 0.6649
# Epoch 95/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0706 - accuracy: 0.9765
# Epoch 00095: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 71s 517ms/step - loss: 0.0706 - accuracy: 0.9765 - val_loss: 1.5703 - val_accuracy: 0.6642
# Epoch 96/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.9771
# Epoch 00096: val_accuracy did not improve from 0.66644
# 138/138 [==============================] -
val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 74s 539ms/step - loss: 0.0609 - accuracy: 0.9806 - val_loss: 1.5711 - val_accuracy: 0.6628
# Epoch 138/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9794
# Epoch 00138: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 74s 539ms/step - loss: 0.0643 - accuracy: 0.9794 - val_loss: 1.5703 - val_accuracy: 0.6626
# Epoch 139/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9796
# Epoch 00139: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 75s 540ms/step - loss: 0.0627 - accuracy: 0.9796 - val_loss: 1.5718 - val_accuracy: 0.6621
# Epoch 140/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 0.9801
# Epoch 00140: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
#
# Epoch 00140: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 74s 538ms/step - loss: 0.0604 - accuracy: 0.9801 - val_loss: 1.5693 - val_accuracy: 0.6626
# Epoch 141/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0667 - accuracy: 0.9783
# Epoch 00141: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 74s 535ms/step - loss: 0.0667 - accuracy: 0.9783 - val_loss: 1.5711 - val_accuracy: 0.6628
# Epoch 142/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.9795
# Epoch 00142: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 74s 538ms/step - loss: 0.0629 - accuracy: 0.9795 - val_loss: 1.5719 - val_accuracy: 0.6621
# Epoch 143/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9782
# Epoch 00143: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 74s 538ms/step - loss: 0.0672 - accuracy: 0.9782 - val_loss: 1.5722 - val_accuracy: 0.6617
# Epoch 144/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0660 - accuracy: 0.9782
# Epoch 00144: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 75s 540ms/step - loss: 0.0660 - accuracy: 0.9782 - val_loss: 1.5708 - val_accuracy: 0.6621
# Epoch 145/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9800
# Epoch 00145: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 74s 538ms/step - loss: 0.0642 - accuracy: 0.9800 - val_loss: 1.5726 - val_accuracy: 0.6619
# Epoch 146/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0632 - accuracy: 0.9787
# Epoch 00146: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 74s 539ms/step - loss: 0.0632 - accuracy: 0.9787 - val_loss: 1.5717 - val_accuracy: 0.6624
# Epoch 147/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0588 - accuracy: 0.9801
# Epoch 00147: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 74s 539ms/step - loss: 0.0588 - accuracy: 0.9801 - val_loss: 1.5717 - val_accuracy: 0.6619
# Epoch 148/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0644 - accuracy: 0.9791
# Epoch 00148: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 75s 541ms/step - loss: 0.0644 - accuracy: 0.9791 - val_loss: 1.5718 - val_accuracy: 0.6630
# Epoch 149/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0648 - accuracy: 0.9789
# Epoch 00149: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 74s 539ms/step - loss: 0.0648 - accuracy: 0.9789 - val_loss: 1.5727 - val_accuracy: 0.6619
# Epoch 150/150
# 138/138 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9789
# Epoch 00150: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
#
# Epoch 00150: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 74s 538ms/step - loss: 0.0643 - accuracy: 0.9789 - val_loss: 1.5704 - val_accuracy: 0.6626

# %%
epoch_str = '-EPOCHS_' + str(EPOCHS)
dropout_str = '-DROPOUT_' + str(DROPOUT_RATE)
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
plt.savefig('./../results/baseline' + epoch_str + dropout_str + '-accuracy.png')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
plt.savefig('./../results/baseline' + epoch_str + dropout_str + '-loss.png')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
print('\n# Evaluate on validation data')
results_val = model.evaluate(val_ds, batch_size=BS)
print('validation loss, validation accuracy:', results_val)
# Out:
# # Evaluate on validation data
# 35/35 [==============================] - 3s 97ms/step - loss: 1.5704 - accuracy: 0.6626
# validation loss, validation accuracy: [1.5703985691070557, 0.662582278251648]

# %%
print('\n# Evaluate on test data')
results_test = model.evaluate(test_ds, batch_size=BS)
print('test loss, test accuracy:', results_test)
# Out:
# # Evaluate on test data
# 44/44 [==============================] - 5s 120ms/step - loss: 1.5137 - accuracy: 0.6751
# test loss, test accuracy: [1.5137064456939697, 0.6750725507736206]

# %%
test_acc = '-test_acc_%.3f' % results_test[1]
model.save('./baseline' + epoch_str + dropout_str + test_acc + '.h5')
